# %% [markdown]
# # A COMPLETE PANDAS TUTORIAL

# %%
# IMPORTING MODULES

import numpy as np
import pandas as pd

train = pd.read_csv('train.csv')
df=train.copy()

# %% [markdown]
# ## THE BASIC

# %%
# See the first 5 rows
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Last 5 rows
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# n_samples x n_features
df.shape
# Out:
# (891, 12)

# %%
#List of all columns
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Rows index
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
# Values in a particular column
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# General description of dataset
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## Creating Dataframe

# %%
# empty data frame
df_empty=pd.DataFrame()
df_empty.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# From dict
student_dict={'Name':['A','B','C'], 'Age':[24,18,17], 'Roll':[1,2,3]}
df_student=pd.DataFrame(student_dict).reset_index(drop=True)
df_student.head()
# Out:
#   Name  Age  Roll
# 0    A   24     1
# 1    B   18     2
# 2    C   17     3

# %% [markdown]
# ## Treating null values

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %% [markdown]
# Impute null values

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Sex'].fillna(df['Sex'].mode(),inplace=True)
df['Sex'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Modify/Add new column(s)

# %% [markdown]
# Adding another column or modify a column

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Sex']=df['Sex'].map({"male":'0',"female":"1"})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
# Finding last name and first name from Name column
df['last_name']=df['Name'].apply(lambda x: x.split(',')[0])
df['first_name']=df['Name'].apply(lambda x: ' '.join(x.split(',')[1:]))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name
# 0                              Mr. Owen Harris
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry

# %%
# Sets to 1 for men in 3rd class
df['Thrid&Men']=df.apply(lambda row: int (row['Pclass']==3 and row['Sex']=="0"),axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Thrid&Men
# 0                              Mr. Owen Harris          1
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0
# 2                                  Miss. Laina          0
# 3           Mrs. Jacques Heath (Lily May Peel)          0
# 4                            Mr. William Henry          1

# %%
# Calling some custom function
def findAgeGroup(age):
    if age<18:
        return 1
    elif age >= 18 and age<40:
        return 2
    elif age >= 40 and age < 60:
        return 3
    else:
        return 4
df['Age_group']=df['Age'].apply(lambda x: findAgeGroup(x))
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Thrid&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %% [markdown]
# ## Deleting Columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Thrid&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
df=df.drop(['PassengerId'],axis=1)
#df=df.drop(['PassengerId'],axis=1,inplace=True)
df.head()
# Out:
#    Survived  Pclass                                               Name Sex  \
# 0         0       3                            Braund, Mr. Owen Harris   0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1
# 2         1       3                             Heikkinen, Miss. Laina   1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1
# 4         0       3                           Allen, Mr. William Henry   0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked  last_name  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                     first_name  Thrid&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %% [markdown]
# # Renaming Columns

# %%
# Lets rename some columns
df=df.rename(columns={'Sex':'Gender','Name':'Full Name','last_name':'Surname','first_name':'Name'})
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Thrid&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %% [markdown]
# # Slicing DataFrame

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Thrid&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
# All rows with pclass==3
df_third_class=df[df['Pclass']==3].reset_index(drop=True) # w/0 drop=True it actually adds a index column rather.
df_third_class.head()
# Out:
#    Survived  Pclass                       Full Name Gender   Age  SibSp  \
# 0         0       3         Braund, Mr. Owen Harris      0  22.0      1
# 1         1       3          Heikkinen, Miss. Laina      1  26.0      0
# 2         0       3        Allen, Mr. William Henry      0  35.0      0
# 3         0       3                Moran, Mr. James      0   NaN      0
# 4         0       3  Palsson, Master. Gosta Leonard      0   2.0      3
#
#    Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 2      0            373450   8.0500   NaN        S      Allen
# 3      0            330877   8.4583   NaN        Q      Moran
# 4      1            349909  21.0750   NaN        S    Palsson
#
#                      Name  Thrid&Men  Age_group
# 0         Mr. Owen Harris          1          2
# 1             Miss. Laina          0          2
# 2       Mr. William Henry          1          2
# 3               Mr. James          1          4
# 4   Master. Gosta Leonard          1          1

# %%
# Females with age > 60
df_aged=df[(df['Age']>60) & (df['Gender']=="1")]
df_aged.head()
# Out:
#      Survived  Pclass                                  Full Name Gender   Age  \
# 275         1       1          Andrews, Miss. Kornelia Theodosia      1  63.0
# 483         1       3                     Turkula, Mrs. (Hedwig)      1  63.0
# 829         1       1  Stone, Mrs. George Nelson (Martha Evelyn)      1  62.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked  Surname  \
# 275      1      0   13502  77.9583    D7        S  Andrews
# 483      0      0    4134   9.5875   NaN        S  Turkula
# 829      0      0  113572  80.0000   B28      NaN    Stone
#
#                                     Name  Thrid&Men  Age_group
# 275             Miss. Kornelia Theodosia          0          4
# 483                        Mrs. (Hedwig)          0          4
# 829   Mrs. George Nelson (Martha Evelyn)          0          4

# %%
# Selecting some particular columns.
df1=df[['Age','Pclass','Gender']]
df1.head()
# Out:
#     Age  Pclass Gender
# 0  22.0       3      0
# 1  38.0       1      1
# 2  26.0       3      1
# 3  35.0       1      1
# 4  35.0       3      0

# %%
# Select numerical columns only
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

df_num = df.select_dtypes(include=numerics)
df_num.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Thrid&Men  Age_group
# 0         0       3  22.0      1      0   7.2500          1          2
# 1         1       1  38.0      1      0  71.2833          0          2
# 2         1       3  26.0      0      0   7.9250          0          2
# 3         1       1  35.0      1      0  53.1000          0          2
# 4         0       3  35.0      0      0   8.0500          1          2

# %%
# categorical columns
df_cat=df.select_dtypes(include=['object'])
df_cat.head()
# Out:
#                                            Full Name Gender            Ticket  \
# 0                            Braund, Mr. Owen Harris      0         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1          PC 17599
# 2                             Heikkinen, Miss. Laina      1  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1            113803
# 4                           Allen, Mr. William Henry      0            373450
#
#   Cabin Embarked    Surname                                         Name
# 0   NaN        S     Braund                              Mr. Owen Harris
# 1   C85        C    Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2   NaN        S  Heikkinen                                  Miss. Laina
# 3  C123        S   Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 4   NaN        S      Allen                            Mr. William Henry

# %% [markdown]
# ## Slicing using iloc and loc

# %% [markdown]
# iloc

# %%
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Thrid&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
df_sub1=df.iloc[0:100,:]
df_sub1.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
#                                           Name  Thrid&Men  Age_group
# 0                              Mr. Owen Harris          1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)          0          2
# 2                                  Miss. Laina          0          2
# 3           Mrs. Jacques Heath (Lily May Peel)          0          2
# 4                            Mr. William Henry          1          2

# %%
#First 250 rows with a subset of columns

#df_sub2=df.iloc[:250,['Age']] 
# This will throw an error as iloc only consumes integres as indices.

df_sub2=df.iloc[:250,[1,8]] 
#Returns first 250 rows and columns at those indices in df.columns.
df_sub2.head()
# Out:
#    Pclass     Fare
# 0       3   7.2500
# 1       1  71.2833
# 2       3   7.9250
# 3       1  53.1000
# 4       3   8.0500

# %% [markdown]
# ## Adding a row

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Adding row using 'append' function
row=dict({'Age':24, 'Full Name':'Peter', 'Survived':'Y'})
df=df.append(row,ignore_index=True)
#assumes Nan for absent keys(columns)
df.tail()
# Out:
#      PassengerId Survived  Pclass                                      Name  \
# 887        888.0        1     1.0              Graham, Miss. Margaret Edith
# 888        889.0        0     3.0  Johnston, Miss. Catherine Helen "Carrie"
# 889        890.0        1     1.0                     Behr, Mr. Karl Howell
# 890        891.0        0     3.0                       Dooley, Mr. Patrick
# 891          NaN        Y     NaN                                       NaN
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked Full Name
# 887  female  19.0    0.0    0.0      112053  30.00   B42        S       NaN
# 888  female   NaN    1.0    2.0  W./C. 6607  23.45   NaN        S       NaN
# 889    male  26.0    0.0    0.0      111369  30.00  C148        C       NaN
# 890    male  32.0    0.0    0.0      370376   7.75   NaN        Q       NaN
# 891     NaN  24.0    NaN    NaN         NaN    NaN   NaN      NaN     Peter

# %%
# Adding new row using loc
df.loc[len(df.index)]=row
df.tail()
# Out:
#      PassengerId Survived  Pclass                                      Name  \
# 888        889.0        0     3.0  Johnston, Miss. Catherine Helen "Carrie"
# 889        890.0        1     1.0                     Behr, Mr. Karl Howell
# 890        891.0        0     3.0                       Dooley, Mr. Patrick
# 891          NaN        Y     NaN                                       NaN
# 892          NaN        Y     NaN                                       NaN
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked Full Name
# 888  female   NaN    1.0    2.0  W./C. 6607  23.45   NaN        S       NaN
# 889    male  26.0    0.0    0.0      111369  30.00  C148        C       NaN
# 890    male  32.0    0.0    0.0      370376   7.75   NaN        Q       NaN
# 891     NaN  24.0    NaN    NaN         NaN    NaN   NaN      NaN     Peter
# 892     NaN  24.0    NaN    NaN         NaN    NaN   NaN      NaN     Peter

# %% [markdown]
# ## Dropping rows

# %%
df=df.drop(df.index[-1],axis=0) # Delete last row
df.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0          1.0        0     3.0
# 1          2.0        1     1.0
# 2          3.0        1     3.0
# 3          4.0        1     1.0
# 4          5.0        0     3.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked Full Name
# 0    0.0         A/5 21171   7.2500   NaN        S       NaN
# 1    0.0          PC 17599  71.2833   C85        C       NaN
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S       NaN
# 3    0.0            113803  53.1000  C123        S       NaN
# 4    0.0            373450   8.0500   NaN        S       NaN

# %% [markdown]
# ## Sorting

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0          1.0        0     3.0
# 1          2.0        1     1.0
# 2          3.0        1     3.0
# 3          4.0        1     1.0
# 4          5.0        0     3.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked Full Name
# 0    0.0         A/5 21171   7.2500   NaN        S       NaN
# 1    0.0          PC 17599  71.2833   C85        C       NaN
# 2    0.0  STON/O2. 3101282   7.9250   NaN        S       NaN
# 3    0.0            113803  53.1000  C123        S       NaN
# 4    0.0            373450   8.0500   NaN        S       NaN

# %%
# Sorting by age say in decreasing order
df=df.sort_values(by=['Age'],ascending=False) # can specify multiple columns as well
df.head()
# Out:
#      PassengerId Survived  Pclass                                  Name   Sex  \
# 630        631.0        1     1.0  Barkworth, Mr. Algernon Henry Wilson  male
# 851        852.0        0     3.0                   Svensson, Mr. Johan  male
# 96          97.0        0     1.0             Goldschmidt, Mr. George B  male
# 493        494.0        0     1.0               Artagaveytia, Mr. Ramon  male
# 116        117.0        0     3.0                  Connors, Mr. Patrick  male
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked Full Name
# 630  80.0    0.0    0.0     27042  30.0000   A23        S       NaN
# 851  74.0    0.0    0.0    347060   7.7750   NaN        S       NaN
# 96   71.0    0.0    0.0  PC 17754  34.6542    A5        C       NaN
# 493  71.0    0.0    0.0  PC 17609  49.5042   NaN        C       NaN
# 116  70.5    0.0    0.0    370369   7.7500   NaN        Q       NaN

# %% [markdown]
# ## Joins

# %% [markdown]
# Let's create two separate data frames and try all 5 (Cross,Inner, Left, Right,and Outer Joins).

# %%
sno=[i+1 for i in range(100)]
marks=np.random.randint(100,size=100)
print(len(marks))
marks_df=pd.DataFrame({'Sno':sno,'Marks':marks})
marks_df.head()
# Out:
# 100
#    Sno  Marks
# 0    1     55
# 1    2     83
# 2    3     15
# 3    4     88
# 4    5     17

# %%
sno=[i+1 for i in range(100)]
age=np.random.randint(100,size=100)
print(len(marks))
age_df=pd.DataFrame({'Sno':sno,'Age':age})
age_df.head()
# Out:
# 100
#    Sno  Age
# 0    1   86
# 1    2   48
# 2    3   56
# 3    4   84
# 4    5   40

# %% [markdown]
# Cross join

# %%
cross_join=pd.merge(marks_df,age_df,how='cross')
print(cross_join.shape)
cross_join.head()
# Out:
# (10000, 4)
#    Sno_x  Marks  Sno_y  Age
# 0      1     55      1   86
# 1      1     55      2   48
# 2      1     55      3   56
# 3      1     55      4   84
# 4      1     55      5   40

# %% [markdown]
# Inner join

# %%
inner_join=pd.merge(age_df,marks_df,how='inner',on='Sno') # 'how' defaults to 'inner' only.
print(inner_join.shape)
inner_join.head()
# Out:
# (100, 3)
#    Sno  Age  Marks
# 0    1   86     55
# 1    2   48     83
# 2    3   56     15
# 3    4   84     88
# 4    5   40     17

# %% [markdown]
# Left and Right Outer Join(s)

# %%
age_df.loc[len(age_df.index)]={'Sno':101,'Age':23}
age_df.loc[len(age_df.index)]={'Sno':102,'Age':27}
age_df.loc[len(age_df.index)]={'Sno':104,'Age':29}
age_df.loc[len(age_df.index)]={'Sno':103,'Age':32}
age_df.loc[len(age_df.index)]={'Sno':105,'Age':53}

# %%
#left join
left_join=pd.merge(age_df,marks_df,how='left',on='Sno')
print(left_join.shape)
left_join.tail()
# Out:
# (105, 3)
#      Sno  Age  Marks
# 100  101   23    NaN
# 101  102   27    NaN
# 102  104   29    NaN
# 103  103   32    NaN
# 104  105   53    NaN

# %%
# Marks=Nan confirms the left join
#right join
right_join=pd.merge(marks_df,age_df,how='right',on='Sno')
print(right_join.shape)
right_join.tail()
# Out:
# (105, 3)
#      Sno  Marks  Age
# 100  101    NaN   23
# 101  102    NaN   27
# 102  104    NaN   29
# 103  103    NaN   32
# 104  105    NaN   53

# %% [markdown]
# Full outer join

# %%
marks_df.loc[len(marks_df.index)]={'Sno':106,'Marks':79}
marks_df.tail()
# Out:
#      Sno  Marks
# 96    97     92
# 97    98     91
# 98    99     82
# 99   100     71
# 100  106     79

# %%
#outer join
out_join=pd.merge(marks_df,age_df,how='outer',on='Sno')
print(out_join.shape)
out_join.tail(10)
# Out:
# (106, 3)
#      Sno  Marks   Age
# 96    97   92.0  28.0
# 97    98   91.0  13.0
# 98    99   82.0  17.0
# 99   100   71.0  98.0
# 100  106   79.0   NaN
# 101  101    NaN  23.0
# 102  102    NaN  27.0
# 103  104    NaN  29.0
# 104  103    NaN  32.0
# 105  105    NaN  53.0

# %% [markdown]
# ## Groupby

# %%
df.head()
# Out:
#      PassengerId Survived  Pclass                                  Name   Sex  \
# 630        631.0        1     1.0  Barkworth, Mr. Algernon Henry Wilson  male
# 851        852.0        0     3.0                   Svensson, Mr. Johan  male
# 96          97.0        0     1.0             Goldschmidt, Mr. George B  male
# 493        494.0        0     1.0               Artagaveytia, Mr. Ramon  male
# 116        117.0        0     3.0                  Connors, Mr. Patrick  male
#
#       Age  SibSp  Parch    Ticket     Fare Cabin Embarked Full Name
# 630  80.0    0.0    0.0     27042  30.0000   A23        S       NaN
# 851  74.0    0.0    0.0    347060   7.7750   NaN        S       NaN
# 96   71.0    0.0    0.0  PC 17754  34.6542    A5        C       NaN
# 493  71.0    0.0    0.0  PC 17609  49.5042   NaN        C       NaN
# 116  70.5    0.0    0.0    370369   7.7500   NaN        Q       NaN

# %% [markdown]
# Before, we move onto Groupby in pandas, lets recollect groupby from SQL. A SQL query, may contain hese parts (some might be optional like having etc...):
# Table name (from)
# Some condition to filter rows (where clause)
# Attribute to groupby on (groupby attributes)
# Filter rows after groupby (having clause)
# Display attributes in the final result. (select)

# %%
groups=df.groupby(['Pclass'])
# uncomment this: 
# groups.groups
groups.get_group(1) # Give some another no say 2 or 3 for its Pclass.
# Out:
#      PassengerId Survived  Pclass  \
# 630        631.0        1     1.0
# 96          97.0        0     1.0
# 493        494.0        0     1.0
# 745        746.0        0     1.0
# 54          55.0        0     1.0
# ..           ...      ...     ...
# 766        767.0        0     1.0
# 793        794.0        0     1.0
# 815        816.0        0     1.0
# 839        840.0        1     1.0
# 849        850.0        1     1.0
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 630          Barkworth, Mr. Algernon Henry Wilson    male  80.0    0.0    0.0
# 96                      Goldschmidt, Mr. George B    male  71.0    0.0    0.0
# 493                       Artagaveytia, Mr. Ramon    male  71.0    0.0    0.0
# 745                  Crosby, Capt. Edward Gifford    male  70.0    1.0    1.0
# 54                 Ostby, Mr. Engelhart Cornelius    male  65.0    0.0    1.0
# ..                                            ...     ...   ...    ...    ...
# 766                     Brewe, Dr. Arthur Jackson    male   NaN    0.0    0.0
# 793                      Hoyt, Mr. William Fisher    male   NaN    0.0    0.0
# 815                              Fry, Mr. Richard    male   NaN    0.0    0.0
# 839                          Marechal, Mr. Pierre    male   NaN    0.0    0.0
# 849  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female   NaN    1.0    0.0
#
#         Ticket     Fare Cabin Embarked Full Name
# 630      27042  30.0000   A23        S       NaN
# 96    PC 17754  34.6542    A5        C       NaN
# 493   PC 17609  49.5042   NaN        C       NaN
# 745  WE/P 5735  71.0000   B22        S       NaN
# 54      113509  61.9792   B30        C       NaN
# ..         ...      ...   ...      ...       ...
# 766     112379  39.6000   NaN        C       NaN
# 793   PC 17600  30.6958   NaN        C       NaN
# 815     112058   0.0000  B102        S       NaN
# 839      11774  29.7000   C47        C       NaN
# 849      17453  89.1042   C92        C       NaN
#
# [216 rows x 13 columns]

# %% [markdown]
# Average Age per Pclass

# %%
df_grp1=df.groupby(['Pclass'])
#df_grp1.head()

# %%
#Average Age per Pclass
df_grp1['Age'].mean()
# Out:
# Pclass
# 1.0    38.233441
# 2.0    29.877630
# 3.0    25.140620
# Name: Age, dtype: float64

# %%
# Min/Max age per Pclass
df_grp1['Age'].min() #max()
# Out:
# Pclass
# 1.0    0.92
# 2.0    0.67
# 3.0    0.42
# Name: Age, dtype: float64

# %%
# Count
df_grp1['Age'].count()
# Out:
# Pclass
# 1.0    186
# 2.0    173
# 3.0    355
# Name: Age, dtype: int64

# %% [markdown]
# Using agg() function

# %%
df=train.copy()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Average per Pclass using 'agg' this time
df_grp2=df.groupby(['Pclass']).agg({'Age':lambda x: np.mean(x)}) 
df_grp2.head()
# Out:
#               Age
# Pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %%
# Min/Max,count,Sum for each Pclass usign agg function
df_grp3=df.groupby(['Pclass']).agg({'Age':'min'}).rename(columns={'Age':'Min Age'})
# Use 'max'/'sum' etc. for that operation. Note that this ignores 'nan' values.
df_grp3.head()
# Out:
#         Min Age
# Pclass
# 1          0.92
# 2          0.67
# 3          0.42

# %%
# Names of all the pasengers in that class.
df_grp4=df.groupby(['Pclass']).agg({'Name':lambda x:', '.join(x)})
df_grp4.head()
# Out:
#                                                      Name
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       Nasser, Mrs. Nicholas (Adele Achem), Hewlett, ...
# 3       Braund, Mr. Owen Harris, Heikkinen, Miss. Lain...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_grp5=df.groupby(['Pclass']).agg({'Age':['max','min']})
df_grp5.head() # MultiOndex Dataframe
# Out:
#          Age
#          max   min
# Pclass
# 1       80.0  0.92
# 2       70.0  0.67
# 3       74.0  0.42

# %% [markdown]
# ## Bonus: Iterating over rows in dataframe

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
for index,row in df.iterrows():
    # do something with row, say:
    #print(row)
    pass
